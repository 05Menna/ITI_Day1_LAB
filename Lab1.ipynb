# %% [markdown]
# # LAB 1

# %% [markdown]
# ## 1-Experiment

# %%
class Experiment:
    belongs_to = 'ITI AI Lab'
    def __init__(self,name,researcher,score):
        self.name = name
        self.researcher = researcher
        self._score = score
    @property
    def score(self):
        return self._score
    @score.setter
    def score(self,value):
        if 0 <= value <= 1:
            self._score=value
        else:
            raise ValueError("Score must be between 0 & 1")

    @staticmethod
    def dict_to_object(dictionary):
        return Experiment(dictionary["name"],dictionary["researcher"],dictionary["score"])

# %%
experiment_data = { "name": "Sentiment Analysis",
                    "researcher": "Ahmed",
                    "score": 0.87
}               
exp = Experiment.dict_to_object(experiment_data)
print(exp.__dict__)
# Out:
# {'name': 'Sentiment Analysis', 'researcher': 'Ahmed', '_score': 0.87}

# %%
exp1=Experiment("Sentiment","Menna",9)
print(exp1.belongs_to)
print(exp1.__dict__)
print(Experiment.__dict__)
# Out:
# ITI AI Lab
# {'name': 'Sentiment', 'researcher': 'Menna', '_score': 9}
# {'__module__': '__main__', '__firstlineno__': 1, 'belongs_to': 'ITI AI Lab', '__init__': <function Experiment.__init__ at 0x000001D0A4048040>, 'score': <property object at 0x000001D0A4129850>, 'dict_to_object': <staticmethod(<function Experiment.dict_to_object at 0x000001D0A4049800>)>, '__static_attributes__': ('_score', 'name', 'researcher'), '__dict__': <attribute '__dict__' of 'Experiment' objects>, '__weakref__': <attribute '__weakref__' of 'Experiment' objects>, '__doc__': None}

# %% [markdown]
# ## 2. Different Experiment Types
